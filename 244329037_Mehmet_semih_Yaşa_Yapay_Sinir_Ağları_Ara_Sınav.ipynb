# %% [markdown]
# <a href="https://colab.research.google.com/github/msemihyasa/Semih/blob/main/244329037_Mehmet_semih_Ya%C5%9Fa_Yapay_Sinir_A%C4%9Flar%C4%B1_Ara_S%C4%B1nav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ÜSKÜDAR ÜNİVERSİTESİ Yapay Sinir Ağları Ara Sınav Ödevi

# %%
# !pip install optuna
# !pip install shap
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 9.0 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.50.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
import shap
import warnings

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, confusion_matrix, roc_curve, auc)
from sklearn.preprocessing import label_binarize

warnings.filterwarnings('ignore')

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

print("Kütüphaneler yüklendi ve hazır.")
# Out:
# Kütüphaneler yüklendi ve hazır.

# %% [markdown]
# ### 1. Veri Setinin Yüklenmesi

# %% [markdown]
# #### 1.1 scikit-learn’den Veri Seti Yükleme

# %%
data = load_wine()

# %% [markdown]
# #### 1.2 Veri Çerçevesi Oluşturma

# %%
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target, name='target')

# Veri setini birleştirip ilk 5 satırı gösterme
df = pd.concat([X, y], axis=1)
print("Veri Seti İlk 5 Satır:")
display(df.head())
# Out:
# Veri Seti İlk 5 Satır:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0

# %% [markdown]
# ### 2. Veri Seti Kalite Kontrolleri

# %% [markdown]
# #### 2.1 Eksik Değer Analizi

# %%
missing_values = df.isnull().sum()
print("\nEksik Değerler:\n", missing_values[missing_values > 0])
if missing_values.sum() == 0:
    print("-> Veri setinde eksik değer bulunmamaktadır.")
# Out:
# Eksik Değerler:
#  Series([], dtype: int64)
# -> Veri setinde eksik değer bulunmamaktadır.

# %% [markdown]
# #### 2.2 Aykırı Değer (Outlier) Analizi

# %%
def detect_outliers_iqr(dataframe, features):
    outlier_indices = []
    for col in features:
        Q1 = dataframe[col].quantile(0.25)
        Q3 = dataframe[col].quantile(0.75)
        IQR = Q3 - Q1
        outlier_step = 1.5 * IQR
        outlier_list_col = dataframe[(dataframe[col] < Q1 - outlier_step) | (dataframe[col] > Q3 + outlier_step)].index
        outlier_indices.extend(outlier_list_col)
    return list(set(outlier_indices))

outliers = detect_outliers_iqr(df, X.columns)

print(f"Outliers: {outliers}")
# Out:
# Outliers: [159, 121, 69, 166, 158, 137, 59, 73, 173, 78, 110, 115, 151, 25, 123, 95, 127]

# %% [markdown]
# #### 2.3 Veri Tipi ve Dağılım İncelemesi

# %%
print(f"-> IQR yöntemi ile tespit edilen benzersiz aykırı değer sayısı: {len(outliers)}")
# Out:
# -> IQR yöntemi ile tespit edilen benzersiz aykırı değer sayısı: 17

# %%
print("\nVeri Tipleri:")
print(df.dtypes)
print(f"\nSınıf Dağılımı:\n{df['target'].value_counts()}")
# Out:
# Veri Tipleri:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# target                            int64
# dtype: object
#
# Sınıf Dağılımı:
# target
# 1    71
# 0    59
# 2    48
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Keşifsel Veri Analizi (EDA)

# %%
print("\n--- 3. Keşifsel Veri Analizi (EDA) ---")

# [cite_start]3.1 İstatistiksel Özellikler [cite: 27, 28]
print("İstatistiksel Özet:")
display(df.describe().T)

# [cite_start]3.2 Korelasyon Matrisi [cite: 34, 35, 36]
plt.figure(figsize=(12, 10))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title("Pearson Korelasyon Matrisi")
plt.show()

# [cite_start]En yüksek korelasyonlu çiftleri bulma [cite: 37]
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
top_corrs = upper_tri.stack().sort_values(ascending=False).head(3)
print("\nEn Yüksek Pozitif Korelasyonlu 3 Çift:\n", top_corrs)

# [cite_start]3.3 Boxplot Analizi [cite: 38, 39]
plt.figure(figsize=(20, 10))
X_melted = pd.melt(df.drop('target', axis=1))
sns.boxplot(x="variable", y="value", data=X_melted)
plt.xticks(rotation=45)
plt.title("Tüm Özellikler İçin Boxplot Analizi")
plt.show()
# Out:
# --- 3. Keşifsel Veri Analizi (EDA) ---
# İstatistiksel Özet:
#                               count        mean         std     min       25%  \
# alcohol                       178.0   13.000618    0.811827   11.03   12.3625
# malic_acid                    178.0    2.336348    1.117146    0.74    1.6025
# ash                           178.0    2.366517    0.274344    1.36    2.2100
# alcalinity_of_ash             178.0   19.494944    3.339564   10.60   17.2000
# magnesium                     178.0   99.741573   14.282484   70.00   88.0000
# total_phenols                 178.0    2.295112    0.625851    0.98    1.7425
# flavanoids                    178.0    2.029270    0.998859    0.34    1.2050
# nonflavanoid_phenols          178.0    0.361854    0.124453    0.13    0.2700
# proanthocyanins               178.0    1.590899    0.572359    0.41    1.2500
# color_intensity               178.0    5.058090    2.318286    1.28    3.2200
# hue                           178.0    0.957449    0.228572    0.48    0.7825
# od280/od315_of_diluted_wines  178.0    2.611685    0.709990    1.27    1.9375
# proline                       178.0  746.893258  314.907474  278.00  500.5000
# target                        178.0    0.938202    0.775035    0.00    0.0000
#
#                                   50%       75%      max
# alcohol                        13.050   13.6775    14.83
# malic_acid                      1.865    3.0825     5.80
# ash                             2.360    2.5575     3.23
# alcalinity_of_ash              19.500   21.5000    30.00
# magnesium                      98.000  107.0000   162.00
# total_phenols                   2.355    2.8000     3.88
# flavanoids                      2.135    2.8750     5.08
# nonflavanoid_phenols            0.340    0.4375     0.66
# proanthocyanins                 1.555    1.9500     3.58
# color_intensity                 4.690    6.2000    13.00
# hue                             0.965    1.1200     1.71
# od280/od315_of_diluted_wines    2.780    3.1700     4.00
# proline                       673.500  985.0000  1680.00
# target                          1.000    2.0000     2.00
# En Yüksek Pozitif Korelasyonlu 3 Çift:
#  total_phenols  flavanoids                      0.864564
# flavanoids     od280/od315_of_diluted_wines    0.787194
# total_phenols  od280/od315_of_diluted_wines    0.699949
# dtype: float64

# %% [markdown]
# Korelasyon Matrisi Yorumu:
# - total_phenols + flavanoids: Bu iki özellik arasındaki çok güçlü pozitif korelasyon beklenen bir durumdur çünkü flavanoidler, toplam fenollerin bir alt grubudur. Şaraptaki fenolik bileşikler tat, renk ve antioksidan özellikler açısından belirleyicidir.
#
# - flavanoids + od280/od315_of_diluted_wines: OD280/OD315 oranı, şaraptaki protein içeriğini ölçen spektroskopik bir parametredir. Flavanoidlerle güçlü ilişkisi, bu bileşiklerin şarabın kimyasal yapısını birlikte etkilediğini gösterir.
#
# - total_phenols + od280/od315_of_diluted_wines: Fenolik bileşiklerin spektroskopik ölçümlerle tutarlı şekilde değişmesi, bu parametrelerin şarap kalitesinin güvenilir göstergeleri olduğunu ortaya koyar.
#
# Target ile Korelasyonlar:
#
# flavanoids (-0.85) ve total_phenols (-0.72) hedef değişkenle en güçlü negatif korelasyona sahiptir, bu da sınıflandırma için en ayırt edici özellikler olduğunu gösterir.

# %% [markdown]
# #### 3.1 İstatistiksel Özellikler

# %%
print("İstatistiksel Özet:")
display(df.describe().T)
# Out:
# İstatistiksel Özet:
#                               count        mean         std     min       25%  \
# alcohol                       178.0   13.000618    0.811827   11.03   12.3625
# malic_acid                    178.0    2.336348    1.117146    0.74    1.6025
# ash                           178.0    2.366517    0.274344    1.36    2.2100
# alcalinity_of_ash             178.0   19.494944    3.339564   10.60   17.2000
# magnesium                     178.0   99.741573   14.282484   70.00   88.0000
# total_phenols                 178.0    2.295112    0.625851    0.98    1.7425
# flavanoids                    178.0    2.029270    0.998859    0.34    1.2050
# nonflavanoid_phenols          178.0    0.361854    0.124453    0.13    0.2700
# proanthocyanins               178.0    1.590899    0.572359    0.41    1.2500
# color_intensity               178.0    5.058090    2.318286    1.28    3.2200
# hue                           178.0    0.957449    0.228572    0.48    0.7825
# od280/od315_of_diluted_wines  178.0    2.611685    0.709990    1.27    1.9375
# proline                       178.0  746.893258  314.907474  278.00  500.5000
# target                        178.0    0.938202    0.775035    0.00    0.0000
#
#                                   50%       75%      max
# alcohol                        13.050   13.6775    14.83
# malic_acid                      1.865    3.0825     5.80
# ash                             2.360    2.5575     3.23
# alcalinity_of_ash              19.500   21.5000    30.00
# magnesium                      98.000  107.0000   162.00
# total_phenols                   2.355    2.8000     3.88
# flavanoids                      2.135    2.8750     5.08
# nonflavanoid_phenols            0.340    0.4375     0.66
# proanthocyanins                 1.555    1.9500     3.58
# color_intensity                 4.690    6.2000    13.00
# hue                             0.965    1.1200     1.71
# od280/od315_of_diluted_wines    2.780    3.1700     4.00
# proline                       673.500  985.0000  1680.00
# target                          1.000    2.0000     2.00

# %% [markdown]
# #### 3.2 Korelasyon Matrisi

# %% [markdown]
# Boxplot Analizi Yorumu
# - magnesium: Üst sınırın üzerinde birkaç outlier mevcut (>140 mg/L). Bu değerler belirli üzüm çeşitlerine veya toprak minerallerine bağlı olabilir.
# - proline: En geniş değer aralığına sahip özellik (278-1680). Outlier görülmemekle birlikte, yüksek varyans modelin bu özelliğe duyarlı olmasına neden olabilir.
# - Ölçek Farkı: Proline (278-1680) ile hue (0.48-1.71) arasındaki büyük ölçek farkı, StandardScaler kullanımının gerekliliğini doğrulamaktadır.
# - Genel Değerlendirme: Tespit edilen 17 aykırı değer, toplam verinin ~%10'unu oluşturmaktadır. Bu değerler doğal varyasyonu temsil edebileceğinden veri setinden çıkarılmamış, bunun yerine StandardScaler ile ölçeklendirme yapılarak etkisi minimize edilmiştir.

# %%
plt.figure(figsize=(12, 10))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title("Pearson Korelasyon Matrisi")
plt.show()

# %% [markdown]
# #### 3.3 Boxplot Analizi

# %%
plt.figure(figsize=(20, 10))
X_melted = pd.melt(df.drop('target', axis=1))
sns.boxplot(x="variable", y="value", data=X_melted)
plt.xticks(rotation=45)
plt.title("Tüm Özellikler İçin Boxplot Analizi")
plt.show()

# %% [markdown]
# ### 4. Veri Setinin Bölünmesi - 5. Veri Ölçeklendirme (Scaling)

# %%
# Hedef: %70 Train, %10 Validation, %20 Test

# Önce %20 Test ayırıyoruz
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=RANDOM_SEED
)

# Kalan %80'lik kısmı Train (%70) ve Validation (%10) olarak ayırıyoruz.
# %80'in 1/8'i %10 eder. Yani kalan verinin 0.125'i validation olmalı.
val_size = 0.125
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=val_size, stratify=y_temp, random_state=RANDOM_SEED
)

print(f"Eğitim Seti Boyutu: {X_train.shape}")
print(f"Validation Seti Boyutu: {X_val.shape}")
print(f"Test Seti Boyutu: {X_test.shape}")

# 5. Veri Ölçeklendirme
scaler = StandardScaler()

# Sadece train set üzerinde fit ediyoruz!
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
X_val_scaled = pd.DataFrame(X_val_scaled, columns=X.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)

print("Veriler StandardScaler ile ölçeklendi.")
# Out:
# Eğitim Seti Boyutu: (124, 13)
# Validation Seti Boyutu: (18, 13)
# Test Seti Boyutu: (36, 13)
# Veriler StandardScaler ile ölçeklendi.

# %% [markdown]
# ### 6. Farklı MLP Modellerinin Kurulması

# %%
# [cite_start]--- 6. Farklı MLP Modellerinin Kurulması [cite: 53, 54] ---

model_configs = [
    # [cite_start]Model 1
    {"name": "Model 1 (Basit)", "params": {"hidden_layer_sizes": (16,), "activation": "relu", "learning_rate_init": 0.001}},
    # [cite_start]Model 2
    {"name": "Model 2 (Orta)", "params": {"hidden_layer_sizes": (32, 16), "activation": "relu", "learning_rate_init": 0.005}},
    # [cite_start]Model 3
    {"name": "Model 3 (Geniş)", "params": {"hidden_layer_sizes": (64, 64), "activation": "tanh", "learning_rate_init": 0.001}},
    # [cite_start]Model 4
    {"name": "Model 4 (Derin)", "params": {"hidden_layer_sizes": (128, 64, 32), "activation": "relu", "learning_rate_init": 0.0005}},
    # [cite_start]Model 5
    {"name": "Model 5 (Düşük LR)", "params": {"hidden_layer_sizes": (32,), "activation": "relu", "learning_rate_init": 0.0001}}
]

# %% [markdown]
# ### 7. Validation Performanslarının Ölçülmesi

# %%
results = []
trained_models = {}

print("\n--- 7. Validation Performanslarının Ölçülmesi---")

for config in model_configs:
    # Modeli Tanımla (Sabit parametreler: max_iter, solver, random_state)
    mlp = MLPClassifier(**config["params"], max_iter=150, random_state=RANDOM_SEED, solver='adam')

    # train et
    mlp.fit(X_train_scaled, y_train)
    trained_models[config["name"]] = mlp

    # validasyon setinde tahmin yap
    y_pred = mlp.predict(X_val_scaled)
    y_proba = mlp.predict_proba(X_val_scaled)

    acc = accuracy_score(y_val, y_pred)
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')
    f1 = f1_score(y_val, y_pred, average='weighted')

    # Multi-class ROC AUC
    try:
        auc_score = roc_auc_score(y_val, y_proba, multi_class='ovr', average='weighted')
    except:
        auc_score = 0 # Hata durumunda (tek sınıf vs)

    results.append({
        "Model": config["name"],
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "F1-Score": f1,
        "ROC-AUC": auc_score
    })


results_df = pd.DataFrame(results)
display(results_df.sort_values(by="F1-Score", ascending=False))

# En iyi modeli seçme
best_model_name = results_df.sort_values(by="F1-Score", ascending=False).iloc[0]["Model"]
best_mlp_manual = trained_models[best_model_name]
print(f"\nSeçilen En İyi Model: {best_model_name}")
# Out:
# --- 7. Validation Performanslarının Ölçülmesi---
#                 Model  Accuracy  Precision    Recall  F1-Score   ROC-AUC
# 1      Model 2 (Orta)  1.000000   1.000000  1.000000  1.000000  1.000000
# 3     Model 4 (Derin)  1.000000   1.000000  1.000000  1.000000  1.000000
# 2     Model 3 (Geniş)  1.000000   1.000000  1.000000  1.000000  1.000000
# 0     Model 1 (Basit)  0.944444   0.952381  0.944444  0.943495  0.990741
# 4  Model 5 (Düşük LR)  0.777778   0.784392  0.777778  0.777778  0.926638
# Seçilen En İyi Model: Model 2 (Orta)

# %% [markdown]
# ### 8. En İyi Modelin Test Üzerinde Değerlendirilmesi

# %% [markdown]
# #### 8.1 Performans Metrikleri

# %%
# [cite_start]--- 8. En İyi Modelin Test Üzerinde Değerlendirilmesi [cite: 83] ---
print(f"\n--- Test Performansı ({best_model_name}) ---")

y_test_pred = best_mlp_manual.predict(X_test_scaled)
y_test_proba = best_mlp_manual.predict_proba(X_test_scaled)

# [cite_start]8.1 Metrikler [cite: 86-91]
print(f"Accuracy: {accuracy_score(y_test, y_test_pred):.4f}")
print(f"Precision: {precision_score(y_test, y_test_pred, average='weighted'):.4f}")
print(f"Recall: {recall_score(y_test, y_test_pred, average='weighted'):.4f}")
print(f"F1-Score: {f1_score(y_test, y_test_pred, average='weighted'):.4f}")
print(f"ROC-AUC: {roc_auc_score(y_test, y_test_proba, multi_class='ovr', average='weighted'):.4f}")
# Out:
# --- Test Performansı (Model 2 (Orta)) ---
# Accuracy: 0.9444
# Precision: 0.9466
# Recall: 0.9444
# F1-Score: 0.9443
# ROC-AUC: 0.9975

# %% [markdown]
# #### 8.2 Confusion Matrix

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=data.target_names, yticklabels=data.target_names)
plt.title("Confusion Matrix (Test Seti)")
plt.xlabel("Tahmin Edilen")
plt.ylabel("Gerçek")
plt.show()

# %% [markdown]
# #### 8.3 ROC Eğrisi

# %%
from sklearn.preprocessing import label_binarize

y_test_bin = label_binarize(y_test, classes=[0, 1, 2])
n_classes = y_test_bin.shape[1]

plt.figure(figsize=(10, 8))
colors = ['blue', 'red', 'green']

# "One-vs-All" (OvA) her bir sınıf için ROC eğrisi çizimi
for i, color in zip(range(n_classes), colors):
    # Her sınıf için diğerlerine karşı ikili bir sınıflandırma problemi olarak ROC eğrisi hesapla
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_test_proba[:, i])
    plt.plot(fpr, tpr, color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'.format(data.target_names[i], auc(fpr, tpr)))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('One-vs-All (OvA) ROC Curves for Each Class')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### 9. Optuna ile Hiperparametre Optimizasyonu (150 Deneme)

# %%
def optuna_objective(trial):
    # Yeni: Öğrenme oranını optimize et
    lr = trial.suggest_float('learning_rate', 1e-5, 1e-2, log=True)

    # ... (Diğer hiperparametreleriniz buraya) ...

    # Model Mimarisi:
    model = tf.keras.Sequential([
        # ... (Katmanlarınız) ...
        tf.keras.layers.Dense(units=3, activation='softmax')
    ])

    # Optimizasyon:
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy', # Doğru kayıp fonksiyonu
                  metrics=['accuracy'])

    # Erken Durdurma (Overfitting'i azaltmak için):
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=batch_size,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping], # Erken Durdurmayı ekle
        verbose=0
    )

    # En İyi Performansı Döndürme:
    # Kritik Düzeltme: Loss yerine Validation Accuracy değerini döndür
    val_accuracy = model.evaluate(X_val, y_val, verbose=0)[1]

    return val_accuracy # Optuna bu değeri maksimize etmeye çalışacaktır

# %%
# 9. Optuna ile Hiperparametre Optimizasyonu
print("\n--- 9. Optuna Optimizasyonu Başlıyor (150 Deneme) ---")

def objective(trial):
    # 9.2 Arama Aralıkları
    n_layers = trial.suggest_int('n_layers', 1, 3)
    layers = []
    for i in range(n_layers):
        layers.append(trial.suggest_int(f'n_units_l{i}', 16, 256))

    hidden_layer_sizes = tuple(layers)

    learning_rate_init = trial.suggest_loguniform('learning_rate_init', 1e-5, 1e-1)
    alpha = trial.suggest_loguniform('alpha', 1e-6, 1e-2)
    activation = trial.suggest_categorical('activation', ["relu", "tanh"])
    solver = trial.suggest_categorical('solver', ["adam", "sgd"])
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64, 128])

    # Model Tanımı
    clf = MLPClassifier(
        hidden_layer_sizes=hidden_layer_sizes,
        learning_rate_init=learning_rate_init,
        alpha=alpha,
        activation=activation,
        solver=solver,
        batch_size=batch_size,
        max_iter=500,
        random_state=RANDOM_SEED
    )

    # 9.3 Eğitim Döngüsü
    clf.fit(X_train_scaled, y_train)
    y_val_pred = clf.predict(X_val_scaled)
    score = f1_score(y_val, y_val_pred, average='weighted')

    return score

# 9.1 Study Tanımı
study = optuna.create_study(direction="maximize")
# Deneme sayısını 150 olarak ayarlıyoruz
study.optimize(objective, n_trials=150, show_progress_bar=True)

# 9.4 En İyi Trial Raporlanması
print("\nEn İyi Parametreler:", study.best_params)
print("En İyi Validation F1-Score:", study.best_value)

# En iyi parametrelerle modeli yeniden oluşturup eğitelim
best_params = study.best_params.copy()
# Layer yapısını parse edelim
n_layers_opt = best_params.pop('n_layers')
layers_opt = []
keys_to_remove = []
for k, v in best_params.items():
    if k.startswith('n_units_l'):
        layers_opt.append(v)
        keys_to_remove.append(k)
for k in keys_to_remove:
    best_params.pop(k)

best_mlp_optuna = MLPClassifier(
    hidden_layer_sizes=tuple(layers_opt),
    **best_params,
    max_iter=1000,
    random_state=RANDOM_SEED
)

best_mlp_optuna.fit(X_train_scaled, y_train)
print("Optuna modeli tüm eğitim verisiyle eğitildi.")
# Out:
# [I 2025-11-30 14:45:28,431] A new study created in memory with name: no-name-18bdf933-38a0-4666-a0c6-263556fef93b
# --- 9. Optuna Optimizasyonu Başlıyor (150 Deneme) ---
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2025-11-30 14:45:29,124] Trial 0 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 36, 'n_units_l1': 186, 'n_units_l2': 85, 'learning_rate_init': 0.028175977012543266, 'alpha': 0.00016923723025838444, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:30,020] Trial 1 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 73, 'n_units_l1': 250, 'n_units_l2': 113, 'learning_rate_init': 0.03183600229201145, 'alpha': 3.5411890219769436e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:42,502] Trial 2 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 132, 'n_units_l1': 149, 'n_units_l2': 56, 'learning_rate_init': 7.4202631805603e-05, 'alpha': 2.392184074776008e-05, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:43,353] Trial 3 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 93, 'learning_rate_init': 0.00014586972255475382, 'alpha': 0.00017673452768171688, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:44,127] Trial 4 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 194, 'n_units_l1': 71, 'learning_rate_init': 0.005547688912848172, 'alpha': 0.0002106498450804123, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:44,448] Trial 5 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 46, 'learning_rate_init': 0.008627221525829497, 'alpha': 0.00016692603637604515, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:44,960] Trial 6 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 183, 'n_units_l1': 54, 'learning_rate_init': 0.0012690182916250024, 'alpha': 2.7539742849841885e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:46,441] Trial 7 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 117, 'n_units_l1': 197, 'n_units_l2': 162, 'learning_rate_init': 0.0008867042767397301, 'alpha': 0.00023701150541816758, 'activation': 'relu', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:51,283] Trial 8 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 92, 'n_units_l1': 131, 'n_units_l2': 148, 'learning_rate_init': 1.1415705883295156e-05, 'alpha': 0.004523995995791378, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:52,575] Trial 9 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 104, 'learning_rate_init': 3.993788223591414e-05, 'alpha': 5.337348995379257e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:52,634] Trial 10 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 16, 'n_units_l1': 251, 'learning_rate_init': 0.0937582812032419, 'alpha': 0.0036603814146328345, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:52,885] Trial 11 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 52, 'n_units_l1': 252, 'n_units_l2': 72, 'learning_rate_init': 0.08792014883345826, 'alpha': 2.2534530835471382e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:54,075] Trial 12 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 255, 'n_units_l1': 194, 'n_units_l2': 242, 'learning_rate_init': 0.014971649628358542, 'alpha': 1.4204728803046897e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:54,321] Trial 13 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 60, 'n_units_l1': 199, 'n_units_l2': 88, 'learning_rate_init': 0.024516439782601866, 'alpha': 0.0009544981076230077, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:54,468] Trial 14 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 24, 'n_units_l1': 147, 'learning_rate_init': 0.0037659422099400684, 'alpha': 6.119187633825845e-06, 'activation': 'relu', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:54,592] Trial 15 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 70, 'n_units_l1': 228, 'learning_rate_init': 0.027166342474515652, 'alpha': 1.0789620763830703e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:55,329] Trial 16 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 157, 'n_units_l1': 107, 'n_units_l2': 119, 'learning_rate_init': 0.0013402129598367278, 'alpha': 0.0008114959208582863, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:55,393] Trial 17 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 71, 'n_units_l1': 216, 'n_units_l2': 24, 'learning_rate_init': 0.03829188864560693, 'alpha': 2.8923670092184178e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:55,878] Trial 18 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 31, 'n_units_l1': 170, 'n_units_l2': 191, 'learning_rate_init': 0.000410656671088919, 'alpha': 0.0006927725514947898, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:56,087] Trial 19 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 82, 'n_units_l1': 27, 'learning_rate_init': 0.0033529800934406708, 'alpha': 9.292815138709983e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:56,150] Trial 20 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 159, 'n_units_l1': 171, 'learning_rate_init': 0.008719229766376848, 'alpha': 5.013717792209801e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:45:58,434] Trial 21 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 133, 'n_units_l1': 113, 'n_units_l2': 50, 'learning_rate_init': 0.00011776080872192428, 'alpha': 2.5195336143028514e-05, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:01,984] Trial 22 finished with value: 0.9444444444444444 and parameters: {'n_layers': 3, 'n_units_l0': 132, 'n_units_l1': 165, 'n_units_l2': 106, 'learning_rate_init': 1.1622779606107445e-05, 'alpha': 4.386173965541493e-06, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:05,807] Trial 23 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 41, 'n_units_l1': 228, 'n_units_l2': 55, 'learning_rate_init': 5.344807259003325e-05, 'alpha': 7.043846116021023e-05, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:07,314] Trial 24 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 236, 'n_units_l1': 143, 'n_units_l2': 95, 'learning_rate_init': 0.0004608508644521247, 'alpha': 1.7709227222990663e-05, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:07,463] Trial 25 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 105, 'n_units_l1': 103, 'n_units_l2': 19, 'learning_rate_init': 0.05151745549699321, 'alpha': 1.272540411845793e-06, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:07,765] Trial 26 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 157, 'n_units_l1': 181, 'n_units_l2': 128, 'learning_rate_init': 0.014477239086867662, 'alpha': 7.619371514759631e-06, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:09,072] Trial 27 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 181, 'n_units_l1': 215, 'learning_rate_init': 0.00012916528513035361, 'alpha': 0.0003550917890273268, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:09,221] Trial 28 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 206, 'n_units_l1': 88, 'n_units_l2': 71, 'learning_rate_init': 0.002325458439505731, 'alpha': 0.00011147711976166607, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:09,633] Trial 29 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 117, 'learning_rate_init': 0.0004310591807195048, 'alpha': 3.959585809448365e-05, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:10,353] Trial 30 finished with value: 0.9448329448329448 and parameters: {'n_layers': 3, 'n_units_l0': 81, 'n_units_l1': 155, 'n_units_l2': 45, 'learning_rate_init': 6.16058976925832e-05, 'alpha': 0.0022832545464233286, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:10,870] Trial 31 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 93, 'learning_rate_init': 0.00014065095191163397, 'alpha': 0.00010330486914686324, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:11,321] Trial 32 finished with value: 0.7611111111111111 and parameters: {'n_layers': 1, 'n_units_l0': 39, 'learning_rate_init': 2.1091913195569122e-05, 'alpha': 0.0003330618181006745, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:11,720] Trial 33 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 66, 'n_units_l1': 123, 'learning_rate_init': 0.00024242944017430115, 'alpha': 0.00016448503779212538, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:12,294] Trial 34 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 117, 'learning_rate_init': 3.252615071016546e-05, 'alpha': 2.5466337539754917e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:12,374] Trial 35 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 51, 'n_units_l1': 228, 'learning_rate_init': 0.006149765972618797, 'alpha': 0.0001863457390970081, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:12,921] Trial 36 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 144, 'learning_rate_init': 7.83793732002549e-05, 'alpha': 0.000357354310395272, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:13,216] Trial 37 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 99, 'n_units_l1': 70, 'n_units_l2': 183, 'learning_rate_init': 0.0007880620184125079, 'alpha': 7.899335455229043e-05, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:13,637] Trial 38 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 83, 'n_units_l1': 185, 'learning_rate_init': 0.0002597196083996866, 'alpha': 0.001601731550770245, 'activation': 'relu', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:13,897] Trial 39 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 107, 'n_units_l1': 210, 'n_units_l2': 76, 'learning_rate_init': 0.013544328114829795, 'alpha': 1.3364237561526463e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:14,145] Trial 40 finished with value: 0.8876543209876543 and parameters: {'n_layers': 1, 'n_units_l0': 59, 'learning_rate_init': 2.1174929341261608e-05, 'alpha': 3.5195379060203042e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:14,224] Trial 41 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 189, 'n_units_l1': 30, 'learning_rate_init': 0.05757735753750556, 'alpha': 0.007401416126417869, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:14,504] Trial 42 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 200, 'n_units_l1': 61, 'learning_rate_init': 0.006943600041164321, 'alpha': 0.0001365426575251084, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:14,651] Trial 43 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 169, 'n_units_l1': 82, 'n_units_l2': 105, 'learning_rate_init': 0.022464996786534568, 'alpha': 0.0005016828678346831, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:15,078] Trial 44 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 233, 'learning_rate_init': 0.0012763926170901128, 'alpha': 0.00023332659747557, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:15,171] Trial 45 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 145, 'n_units_l1': 127, 'n_units_l2': 140, 'learning_rate_init': 0.09751146456388685, 'alpha': 6.401712338307449e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:15,263] Trial 46 finished with value: 0.9444444444444444 and parameters: {'n_layers': 2, 'n_units_l0': 17, 'n_units_l1': 241, 'learning_rate_init': 0.031937735937301585, 'alpha': 3.104369738703336e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:15,530] Trial 47 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 122, 'n_units_l1': 154, 'n_units_l2': 42, 'learning_rate_init': 0.002144214881504281, 'alpha': 0.0011611089236308416, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:15,864] Trial 48 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 32, 'n_units_l1': 137, 'n_units_l2': 115, 'learning_rate_init': 0.019043399982081943, 'alpha': 0.0005023449111548267, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:15,999] Trial 49 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 83, 'n_units_l1': 44, 'learning_rate_init': 0.054937484940495336, 'alpha': 0.00022148253214153624, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:16,791] Trial 50 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 56, 'n_units_l1': 201, 'n_units_l2': 87, 'learning_rate_init': 0.009660518947915885, 'alpha': 1.7239686242872838e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:17,047] Trial 51 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 72, 'learning_rate_init': 0.004341611983968353, 'alpha': 0.00014543406203662386, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:17,125] Trial 52 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 36, 'learning_rate_init': 0.04037152545264727, 'alpha': 8.757838199499653e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:17,213] Trial 53 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 45, 'learning_rate_init': 0.009906187465516608, 'alpha': 0.000289265435773042, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:17,384] Trial 54 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 51, 'learning_rate_init': 0.002303874335242385, 'alpha': 0.00044636759226085064, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:17,452] Trial 55 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 21, 'learning_rate_init': 0.018620111629508565, 'alpha': 4.389795258497895e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:17,641] Trial 56 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 66, 'n_units_l1': 256, 'n_units_l2': 67, 'learning_rate_init': 0.0053335679845655055, 'alpha': 1.8398688601637593e-05, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:18,842] Trial 57 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 224, 'n_units_l1': 98, 'n_units_l2': 159, 'learning_rate_init': 0.0007346489267959799, 'alpha': 5.571390573863251e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:18,935] Trial 58 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 76, 'n_units_l1': 238, 'learning_rate_init': 0.07541342398911832, 'alpha': 0.0006748473533347388, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:18,967] Trial 59 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 25, 'learning_rate_init': 0.03144019313872721, 'alpha': 1.0185685640633846e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:19,432] Trial 60 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 169, 'n_units_l1': 187, 'n_units_l2': 244, 'learning_rate_init': 0.011768717535791505, 'alpha': 0.00011077145578721979, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:20,343] Trial 61 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 206, 'n_units_l1': 16, 'learning_rate_init': 8.588464341780224e-05, 'alpha': 3.19187038832084e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:20,505] Trial 62 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 190, 'n_units_l1': 60, 'learning_rate_init': 0.0031363811234122263, 'alpha': 1.6580087444360678e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:20,999] Trial 63 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 214, 'n_units_l1': 45, 'learning_rate_init': 0.00026439116678077083, 'alpha': 1.013798061031645e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:21,747] Trial 64 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 249, 'n_units_l1': 117, 'n_units_l2': 189, 'learning_rate_init': 0.00018939160503515478, 'alpha': 4.800677358040353e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:23,316] Trial 65 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 175, 'n_units_l1': 92, 'learning_rate_init': 3.466154786711266e-05, 'alpha': 5.564325179663137e-05, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:23,451] Trial 66 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 126, 'n_units_l1': 79, 'n_units_l2': 34, 'learning_rate_init': 0.001560368204842246, 'alpha': 7.030068703285161e-06, 'activation': 'relu', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:24,546] Trial 67 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 150, 'n_units_l1': 168, 'learning_rate_init': 0.0006497257345389106, 'alpha': 0.00018857110871870568, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:24,655] Trial 68 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 47, 'learning_rate_init': 0.007714398863616445, 'alpha': 0.0002755357734312103, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:25,871] Trial 69 finished with value: 0.9434947768281101 and parameters: {'n_layers': 3, 'n_units_l0': 95, 'n_units_l1': 51, 'n_units_l2': 167, 'learning_rate_init': 5.282778912031762e-05, 'alpha': 2.3325854871952217e-05, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:26,138] Trial 70 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 63, 'n_units_l1': 158, 'learning_rate_init': 0.0005601009957176776, 'alpha': 1.9868613260367626e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:26,518] Trial 71 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 108, 'n_units_l1': 203, 'n_units_l2': 214, 'learning_rate_init': 0.00035465637158203577, 'alpha': 0.00014649271160593888, 'activation': 'relu', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:26,683] Trial 72 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 113, 'n_units_l1': 174, 'n_units_l2': 153, 'learning_rate_init': 0.0012587304436680994, 'alpha': 0.00010361349559476047, 'activation': 'relu', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:28,267] Trial 73 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 127, 'n_units_l1': 143, 'n_units_l2': 135, 'learning_rate_init': 9.678850733319085e-05, 'alpha': 7.599656762931924e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:28,639] Trial 74 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 137, 'n_units_l1': 194, 'n_units_l2': 173, 'learning_rate_init': 0.0008986538929592157, 'alpha': 0.00023255693367246064, 'activation': 'relu', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:31,889] Trial 75 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 139, 'n_units_l1': 243, 'n_units_l2': 214, 'learning_rate_init': 0.00015006906935826405, 'alpha': 0.0004027334870338997, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:32,008] Trial 76 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 95, 'learning_rate_init': 0.003095026189342844, 'alpha': 0.000642154506776359, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:32,195] Trial 77 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 88, 'n_units_l1': 178, 'n_units_l2': 62, 'learning_rate_init': 0.016883846804942787, 'alpha': 0.00012511128820820398, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:32,335] Trial 78 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 100, 'n_units_l1': 223, 'learning_rate_init': 0.004899426835115858, 'alpha': 0.00018861701903286895, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:32,500] Trial 79 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 157, 'n_units_l1': 162, 'n_units_l2': 84, 'learning_rate_init': 0.02357885590754479, 'alpha': 9.226695689568178e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:32,554] Trial 80 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 29, 'learning_rate_init': 0.03779842823619309, 'alpha': 3.5856844607099697e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:34,911] Trial 81 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 116, 'n_units_l1': 129, 'n_units_l2': 146, 'learning_rate_init': 2.5848671787174877e-05, 'alpha': 0.006355716437483275, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:37,923] Trial 82 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 78, 'n_units_l1': 109, 'n_units_l2': 122, 'learning_rate_init': 1.5084630200997588e-05, 'alpha': 0.0024056355813162874, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:42,065] Trial 83 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 88, 'n_units_l1': 150, 'n_units_l2': 106, 'learning_rate_init': 1.4632194588297071e-05, 'alpha': 0.0039314503066093945, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:43,448] Trial 84 finished with value: 0.6472222222222221 and parameters: {'n_layers': 3, 'n_units_l0': 71, 'n_units_l1': 34, 'n_units_l2': 91, 'learning_rate_init': 1.0503989986952263e-05, 'alpha': 3.1768111807859505e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:44,379] Trial 85 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 111, 'n_units_l1': 68, 'n_units_l2': 205, 'learning_rate_init': 5.9730884647794844e-05, 'alpha': 2.4513978822106466e-06, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:45,207] Trial 86 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 88, 'n_units_l1': 194, 'n_units_l2': 135, 'learning_rate_init': 0.0017366957844785918, 'alpha': 0.00027597269437296677, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:45,446] Trial 87 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 58, 'n_units_l1': 207, 'learning_rate_init': 0.0010269622325851106, 'alpha': 0.0001729964456160312, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:45,502] Trial 88 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 120, 'learning_rate_init': 0.0732760442721858, 'alpha': 0.001013127907005784, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:45,658] Trial 89 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 100, 'n_units_l1': 136, 'n_units_l2': 151, 'learning_rate_init': 0.012269226876305392, 'alpha': 1.4188541027271084e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:47,735] Trial 90 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 40, 'n_units_l1': 217, 'n_units_l2': 115, 'learning_rate_init': 0.00037728788885286395, 'alpha': 0.00930696619155167, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:48,666] Trial 91 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 104, 'learning_rate_init': 1.5258168139207239e-05, 'alpha': 4.189786054109428e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:49,593] Trial 92 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 127, 'learning_rate_init': 4.47353862783194e-05, 'alpha': 9.17805211379901e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:50,737] Trial 93 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 189, 'learning_rate_init': 3.5915926771864395e-05, 'alpha': 5.979188478110961e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:51,125] Trial 94 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 165, 'learning_rate_init': 0.00011528864067131506, 'alpha': 1.779512186255058e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:52,513] Trial 95 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 202, 'learning_rate_init': 2.4972799842673475e-05, 'alpha': 0.0014273427121917234, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:53,042] Trial 96 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 183, 'learning_rate_init': 0.00018199049018694608, 'alpha': 0.0005329252288616911, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:53,164] Trial 97 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 150, 'n_units_l1': 119, 'n_units_l2': 57, 'learning_rate_init': 0.04481262258951554, 'alpha': 0.00032221910812749415, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:53,929] Trial 98 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 103, 'learning_rate_init': 7.248089559380487e-05, 'alpha': 1.1983594034886612e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:54,051] Trial 99 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 216, 'n_units_l1': 190, 'n_units_l2': 99, 'learning_rate_init': 0.027033616800108105, 'alpha': 6.893754757827985e-05, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:54,222] Trial 100 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 92, 'learning_rate_init': 0.006475170425231839, 'alpha': 4.889981727176586e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:54,276] Trial 101 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 33, 'n_units_l1': 247, 'learning_rate_init': 0.06916119579949334, 'alpha': 0.004400809122467513, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:54,356] Trial 102 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 45, 'n_units_l1': 234, 'learning_rate_init': 0.004052369216460671, 'alpha': 0.004689769415883039, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:54,811] Trial 103 finished with value: 0.9444444444444444 and parameters: {'n_layers': 2, 'n_units_l0': 16, 'n_units_l1': 256, 'learning_rate_init': 4.717659516403593e-05, 'alpha': 0.00013168601987736625, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:54,876] Trial 104 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 132, 'n_units_l1': 249, 'learning_rate_init': 0.09708501016980063, 'alpha': 0.0036551107733461597, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:54,971] Trial 105 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 20, 'n_units_l1': 235, 'n_units_l2': 79, 'learning_rate_init': 0.009100710780273486, 'alpha': 0.002402337176747403, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:56,672] Trial 106 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 80, 'n_units_l1': 228, 'n_units_l2': 29, 'learning_rate_init': 0.0002961241624885746, 'alpha': 0.00022026671041474637, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:56,744] Trial 107 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 27, 'n_units_l1': 217, 'learning_rate_init': 0.015628084890883312, 'alpha': 0.003095771054916428, 'activation': 'relu', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:56,905] Trial 108 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 54, 'learning_rate_init': 0.002798102516015424, 'alpha': 2.9465205686224457e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:57,039] Trial 109 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 35, 'n_units_l1': 102, 'n_units_l2': 127, 'learning_rate_init': 0.02191022605481563, 'alpha': 0.00601032189315069, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:57,416] Trial 110 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 197, 'n_units_l1': 57, 'learning_rate_init': 0.0005007966021551741, 'alpha': 4.490981753104986e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:57,510] Trial 111 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 44, 'n_units_l1': 248, 'n_units_l2': 70, 'learning_rate_init': 0.09127189610547776, 'alpha': 2.132697526856005e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:57,586] Trial 112 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 68, 'n_units_l1': 75, 'n_units_l2': 49, 'learning_rate_init': 0.060884430718039846, 'alpha': 1.3491952264867983e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:57,699] Trial 113 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 61, 'n_units_l1': 227, 'n_units_l2': 100, 'learning_rate_init': 0.08192994341441992, 'alpha': 0.0001580062024436662, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:57,868] Trial 114 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 112, 'n_units_l1': 256, 'n_units_l2': 176, 'learning_rate_init': 0.03538941189030111, 'alpha': 3.609428897369592e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:57,988] Trial 115 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 74, 'n_units_l1': 182, 'n_units_l2': 78, 'learning_rate_init': 0.045214217732235835, 'alpha': 5.969729507481893e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:59,485] Trial 116 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 123, 'n_units_l1': 40, 'n_units_l2': 37, 'learning_rate_init': 0.00010470459710418441, 'alpha': 2.3082036677511438e-05, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:59,595] Trial 117 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 49, 'n_units_l1': 211, 'n_units_l2': 111, 'learning_rate_init': 0.05072136622470847, 'alpha': 0.00010921679819813005, 'activation': 'relu', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:46:59,638] Trial 118 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 39, 'learning_rate_init': 0.030193896065964388, 'alpha': 2.807016054309071e-06, 'activation': 'relu', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:02,321] Trial 119 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 23, 'n_units_l1': 87, 'n_units_l2': 159, 'learning_rate_init': 7.996821649712821e-05, 'alpha': 0.0018863407632802097, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:02,376] Trial 120 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 96, 'n_units_l1': 20, 'learning_rate_init': 0.06540591108885255, 'alpha': 0.0004036271532059939, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:03,316] Trial 121 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 237, 'n_units_l1': 173, 'n_units_l2': 93, 'learning_rate_init': 0.01304231280638086, 'alpha': 1.3025868354029635e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:04,076] Trial 122 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 242, 'n_units_l1': 242, 'n_units_l2': 223, 'learning_rate_init': 0.010670303915224045, 'alpha': 1.91169903877656e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:04,643] Trial 123 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 133, 'n_units_l1': 197, 'n_units_l2': 236, 'learning_rate_init': 0.007651960250881077, 'alpha': 0.00019382024095212412, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:05,047] Trial 124 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 221, 'n_units_l1': 205, 'n_units_l2': 17, 'learning_rate_init': 0.005482337999404438, 'alpha': 3.860072067444137e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:05,279] Trial 125 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 85, 'n_units_l1': 220, 'n_units_l2': 66, 'learning_rate_init': 0.02037089427924118, 'alpha': 8.119651577699449e-05, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:05,848] Trial 126 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 107, 'learning_rate_init': 0.00014702717406865021, 'alpha': 7.338853790548707e-06, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:06,095] Trial 127 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 252, 'n_units_l1': 233, 'n_units_l2': 59, 'learning_rate_init': 0.015712528508861137, 'alpha': 2.7081888777770758e-05, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:06,909] Trial 128 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 139, 'n_units_l1': 251, 'n_units_l2': 191, 'learning_rate_init': 0.00020492527884718903, 'alpha': 9.24176231665212e-06, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:07,836] Trial 129 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 229, 'learning_rate_init': 2.0395152863372402e-05, 'alpha': 1.1506505413119496e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:09,121] Trial 130 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 54, 'n_units_l1': 137, 'n_units_l2': 246, 'learning_rate_init': 4.193779997843871e-05, 'alpha': 1.4619929229501701e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:09,243] Trial 131 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 52, 'n_units_l1': 165, 'n_units_l2': 88, 'learning_rate_init': 0.02625405404805849, 'alpha': 0.0009689707660678607, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:09,396] Trial 132 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 65, 'n_units_l1': 187, 'n_units_l2': 76, 'learning_rate_init': 0.019015543241068703, 'alpha': 0.00024385801879418814, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:09,560] Trial 133 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 118, 'n_units_l1': 179, 'n_units_l2': 256, 'learning_rate_init': 0.03995476629926728, 'alpha': 0.00012392639115630595, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:11,567] Trial 134 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 60, 'n_units_l1': 211, 'n_units_l2': 125, 'learning_rate_init': 6.532618632474893e-05, 'alpha': 0.0030365771310658573, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:11,684] Trial 135 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 41, 'n_units_l1': 196, 'learning_rate_init': 0.031089669532806428, 'alpha': 0.00032521221904503516, 'activation': 'tanh', 'solver': 'sgd', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:11,841] Trial 136 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 68, 'n_units_l1': 147, 'n_units_l2': 84, 'learning_rate_init': 0.0019779274083816635, 'alpha': 2.080488548155712e-05, 'activation': 'relu', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:11,934] Trial 137 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 151, 'learning_rate_init': 0.0522569985255107, 'alpha': 2.469608915691777e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:12,011] Trial 138 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 76, 'n_units_l1': 200, 'n_units_l2': 43, 'learning_rate_init': 0.023553561158604026, 'alpha': 0.005347163142899625, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:12,244] Trial 139 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 30, 'n_units_l1': 53, 'learning_rate_init': 0.010463340484541457, 'alpha': 0.009285266861092312, 'activation': 'relu', 'solver': 'adam', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:12,378] Trial 140 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 92, 'n_units_l1': 69, 'n_units_l2': 54, 'learning_rate_init': 0.013798147359263442, 'alpha': 0.00015163005937974058, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:12,441] Trial 141 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 21, 'n_units_l1': 154, 'learning_rate_init': 0.00811035825411101, 'alpha': 6.2137988004446444e-06, 'activation': 'relu', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:12,515] Trial 142 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 32, 'n_units_l1': 129, 'learning_rate_init': 0.00382532663265677, 'alpha': 4.756051125713199e-06, 'activation': 'relu', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:12,675] Trial 143 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 24, 'n_units_l1': 160, 'learning_rate_init': 0.0010327923108720358, 'alpha': 0.0007663466876735627, 'activation': 'relu', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:12,757] Trial 144 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 49, 'n_units_l1': 190, 'learning_rate_init': 0.005524749708267991, 'alpha': 1.5526793526702775e-05, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:15,143] Trial 145 finished with value: 1.0 and parameters: {'n_layers': 2, 'n_units_l0': 208, 'n_units_l1': 167, 'learning_rate_init': 2.6797998865586422e-05, 'alpha': 3.2027455320418026e-06, 'activation': 'relu', 'solver': 'adam', 'batch_size': 64}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:15,316] Trial 146 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 37, 'learning_rate_init': 0.0028078688795396905, 'alpha': 4.0160701004780535e-06, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:15,774] Trial 147 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 100, 'n_units_l1': 142, 'n_units_l2': 141, 'learning_rate_init': 0.004435114026976802, 'alpha': 1.5399262084310697e-06, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 16}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:16,017] Trial 148 finished with value: 1.0 and parameters: {'n_layers': 3, 'n_units_l0': 256, 'n_units_l1': 115, 'n_units_l2': 98, 'learning_rate_init': 0.001352219580691774, 'alpha': 0.00021312801879647383, 'activation': 'tanh', 'solver': 'adam', 'batch_size': 32}. Best is trial 0 with value: 1.0.
# [I 2025-11-30 14:47:16,335] Trial 149 finished with value: 1.0 and parameters: {'n_layers': 1, 'n_units_l0': 176, 'learning_rate_init': 0.0006976369676044683, 'alpha': 0.00026245889469492863, 'activation': 'relu', 'solver': 'sgd', 'batch_size': 128}. Best is trial 0 with value: 1.0.
#
# En İyi Parametreler: {'n_layers': 3, 'n_units_l0': 36, 'n_units_l1': 186, 'n_units_l2': 85, 'learning_rate_init': 0.028175977012543266, 'alpha': 0.00016923723025838444, 'activation': 'relu', 'solver': 'adam', 'batch_size': 128}
# En İyi Validation F1-Score: 1.0
# Optuna modeli tüm eğitim verisiyle eğitildi.

# %% [markdown]
# ### 10. XAI – SHAP Açıklanabilirlik Analizi (Zorunlu)

# %%
# SHAP için arka plan verisi (K-means özeti)
X_train_summary = shap.kmeans(X_train_scaled, 10)

def run_shap_analysis(model, model_name, X_data):
    print(f"\nAnalyzing: {model_name}")

    explainer = shap.KernelExplainer(model.predict_proba, X_train_summary)

    X_data_np = X_data.values if hasattr(X_data, "values") else X_data
    shap_values = explainer.shap_values(X_data_np)

    # SHAP değerlerinin yapısını kontrol et
    print(f"SHAP values type: {type(shap_values)}")
    if isinstance(shap_values, list):
        print(f"Number of classes: {len(shap_values)}")
        print(f"Shape per class: {shap_values[0].shape}")
    else:
        print(f"SHAP values shape: {shap_values.shape}")
    print(f"X_data shape: {X_data_np.shape}")

    feature_names = list(X_data.columns) if hasattr(X_data, "columns") else data.feature_names

    # Summary Plot (Bar)
    plt.figure()
    plt.title(f"SHAP Summary Bar Plot - {model_name}")
    shap.summary_plot(shap_values, X_data_np, feature_names=feature_names, plot_type="bar", show=False)
    plt.show()

    # Beeswarm için doğru şekilde veri geçir
    print(f"Sınıf 1 ({data.target_names[1]}) için detaylı analiz:")
    plt.figure()
    plt.title(f"SHAP Beeswarm Plot (Class 1) - {model_name}")

    if isinstance(shap_values, list):
        shap.summary_plot(shap_values[1], X_data_np, feature_names=feature_names, show=False)
    else:
        # Eğer 3D array ise (samples, features, classes)
        shap.summary_plot(shap_values[:, :, 1], X_data_np, feature_names=feature_names, show=False)

    plt.show()

    return explainer, shap_values

# %% [markdown]
# #### 10.1 Beş MLP Modelinden validasyon başarısına göre seçilen model için SHAP Analizi

# %%
explainer_manual, shap_values_manual = run_shap_analysis(best_mlp_manual, "Manuel En İyi Model", X_test_scaled)
# Out:
# Analyzing: Manuel En İyi Model
#   0%|          | 0/36 [00:00<?, ?it/s]
# SHAP values type: <class 'numpy.ndarray'>
# SHAP values shape: (36, 13, 3)
# X_data shape: (36, 13)
# Sınıf 1 (class_1) için detaylı analiz:

# %% [markdown]
# #### 10.2 Optuna En İyi Model için SHAP Analizi

# %%
explainer_optuna, shap_values_optuna = run_shap_analysis(best_mlp_optuna, "Optuna En İyi Model", X_test_scaled)
# Out:
# Analyzing: Optuna En İyi Model
#   0%|          | 0/36 [00:00<?, ?it/s]
# SHAP values type: <class 'numpy.ndarray'>
# SHAP values shape: (36, 13, 3)
# X_data shape: (36, 13)
# Sınıf 1 (class_1) için detaylı analiz:

# %%
print("\n" + "="*50)
print("SHAP Force Plot ve Decision Plot Analizi")
print("="*50)

shap.initjs()

# SHAP değerlerinin yapısını kontrol et
if isinstance(shap_values_optuna, list):
    # Eski SHAP yapısı (list of arrays)
    sv_class1 = shap_values_optuna[1]
    expected_val = explainer_optuna.expected_value[1]
else:
    # Yeni SHAP yapısı (3D array: samples x features x classes)
    sv_class1 = shap_values_optuna[:, :, 1]
    expected_val = explainer_optuna.expected_value[1]

# Force Plot - İlk test örneği
print("\nForce Plot (İlk test örneği, Sınıf 1 için):")
plt.figure()
shap.force_plot(expected_val, sv_class1[0, :], X_test_scaled.iloc[0, :], matplotlib=True, show=False)
plt.tight_layout()
plt.show()

# Decision Plot - İlk 10 test örneği
print("\nDecision Plot (İlk 10 test örneği, Sınıf 1 için):")
plt.figure()
shap.decision_plot(expected_val, sv_class1[:10, :], feature_names=list(X_test_scaled.columns), show=False)
plt.tight_layout()
plt.show()
# Out:
# ==================================================
# SHAP Force Plot ve Decision Plot Analizi
# ==================================================
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},l=Symbol.for("react.portal"),u=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:l,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=u.T,n=o.p;try{if(u.T=null,o.p=2,e)return e()}finally{u.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return u.H.useFormState(e,t,n)},t.useFormStatus=function(){return u.H.useHostTransitionStatus()},t.version="19.2.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function l(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function u(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# Force Plot (İlk test örneği, Sınıf 1 için):
# Decision Plot (İlk 10 test örneği, Sınıf 1 için):
